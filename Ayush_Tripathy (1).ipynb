# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = pd.read_csv('/content/drive/MyDrive/Big_Japan_vs_China_Technology.csv')

# %%
a.head(5)
# Out:
#   Country  Year      Tech Sector  Market Share (%)  R&D Investment (in USD)  \
# 0   China  2001         Software         22.279014             8.377208e+10
# 1   Japan  2011    Semiconductor         31.899013             3.551134e+10
# 2   Japan  2009         Robotics         33.574466             8.480948e+10
# 3   Japan  2019  Cloud Computing         24.904248             2.267821e+10
# 4   China  2002         Robotics         46.975827             3.453655e+10
#
#    Number of Patents Filed (Annual)  Number of Tech Companies  \
# 0                              1415                       878
# 1                              7899                       364
# 2                              3749                       425
# 3                              3841                        62
# 4                              1704                       458
#
#    Tech Exports (in USD)  Number of Startups  \
# 0           3.503155e+10                 166
# ...

# %%
a.tail(5)
# Out:
#     Country  Year         Tech Sector  Market Share (%)  \
# 995   Japan  2006       Semiconductor         44.584960
# 996   Japan  2015  Telecommunications         33.390471
# 997   Japan  2020       Biotechnology         14.545372
# 998   Japan  2014  Telecommunications         31.976887
# 999   Japan  2002  Telecommunications         22.120027
#
#      R&D Investment (in USD)  Number of Patents Filed (Annual)  \
# 995             3.888791e+10                              9847
# 996             7.416793e+10                              8443
# 997             2.334538e+10                              3668
# 998             6.013302e+10                              9793
# 999             1.162715e+10                              6973
#
#      Number of Tech Companies  Tech Exports (in USD)  Number of Startups  \
# 995                      1616           3.054285e+10                 327
# 996                       776           1.637671e+10                 336
# ...

# %%
a.shape
# Out:
# (1000, 16)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             1000 non-null   object
#  1   Year                                1000 non-null   int64
#  2   Tech Sector                         1000 non-null   object
#  3   Market Share (%)                    1000 non-null   float64
#  4   R&D Investment (in USD)             1000 non-null   float64
#  5   Number of Patents Filed (Annual)    1000 non-null   int64
#  6   Number of Tech Companies            1000 non-null   int64
#  7   Tech Exports (in USD)               1000 non-null   float64
#  8   Number of Startups                  1000 non-null   int64
#  9   Venture Capital Funding (in USD)    1000 non-null   float64
#  10  Global Innovation Ranking           1000 non-null   int64
# ...

# %%
a.describe()
# Out:
#               Year  Market Share (%)  R&D Investment (in USD)  \
# count  1000.000000       1000.000000             1.000000e+03
# mean   2011.497000         27.439221             5.034591e+10
# std       6.991486         12.808159             2.829704e+10
# min    2000.000000          5.033959             1.056575e+09
# 25%    2005.000000         16.333641             2.558291e+10
# 50%    2012.000000         27.111042             5.010075e+10
# 75%    2017.250000         38.480568             7.492896e+10
# max    2023.000000         49.955344             9.997537e+10
#
#        Number of Patents Filed (Annual)  Number of Tech Companies  \
# count                       1000.000000               1000.000000
# mean                        5094.686000               1011.133000
# std                         2846.164392                563.223321
# min                          119.000000                 52.000000
# 25%                         2789.500000                503.000000
# ...

# %%
a.dtypes
# Out:
# Country                                object
# Year                                    int64
# Tech Sector                            object
# Market Share (%)                      float64
# R&D Investment (in USD)               float64
# Number of Patents Filed (Annual)        int64
# Number of Tech Companies                int64
# Tech Exports (in USD)                 float64
# Number of Startups                      int64
# Venture Capital Funding (in USD)      float64
# Global Innovation Ranking               int64
# Internet Penetration (%)              float64
# 5G Network Coverage (%)               float64
# University Research Collaborations      int64
# Top Tech Products Exported             object
# Number of Tech Workers                  int64
# dtype: object

# %%
a.isna().sum()
# Out:
# Country                               0
# Year                                  0
# Tech Sector                           0
# Market Share (%)                      0
# R&D Investment (in USD)               0
# Number of Patents Filed (Annual)      0
# Number of Tech Companies              0
# Tech Exports (in USD)                 0
# Number of Startups                    0
# Venture Capital Funding (in USD)      0
# Global Innovation Ranking             0
# Internet Penetration (%)              0
# 5G Network Coverage (%)               0
# University Research Collaborations    0
# Top Tech Products Exported            0
# Number of Tech Workers                0
# dtype: int64

# %%
a.sample(2)
# Out:
#     Country  Year      Tech Sector  Market Share (%)  R&D Investment (in USD)  \
# 291   China  2010    Semiconductor         26.904451             1.303404e+10
# 357   China  2022  Cloud Computing         41.587905             9.937390e+10
#
#      Number of Patents Filed (Annual)  Number of Tech Companies  \
# 291                              6794                      1752
# 357                               606                       588
#
#      Tech Exports (in USD)  Number of Startups  \
# 291           1.875592e+11                  54
# 357           7.247998e+10                 486
#
#      Venture Capital Funding (in USD)  Global Innovation Ranking  \
# 291                      2.682666e+10                         15
# 357                      6.941483e+09                          4
#
#      Internet Penetration (%)  5G Network Coverage (%)  \
# 291                 77.216517                18.197126
# 357                 54.279735                14.990726
#
# ...

# %%
# Univariate analysis
# Categorical variables
a['Country'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %%
a['Country'].value_counts().plot(kind = 'bar', title = 'Countries', xlabel = 'country', ylabel = 'counts')
# Out:
# <Axes: title={'center': 'Countries'}, xlabel='country', ylabel='counts'>

# %%
a['Year'].value_counts().plot(kind = 'bar', title = 'years', xlabel = 'year', ylabel = 'counts')
# Out:
# <Axes: title={'center': 'years'}, xlabel='year', ylabel='counts'>

# %%
a['Year'].value_counts().sort_index().plot(kind = 'bar', title = 'years', xlabel = 'year', ylabel = 'counts')
# Out:
# <Axes: title={'center': 'years'}, xlabel='year', ylabel='counts'>

# %%
a['Year'].value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='Year'>

# %%
a['Year'].value_counts().sort_index().plot.area()
# Out:
# <Axes: xlabel='Year'>

# %%
a['Tech Sector'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Tech Sector'>

# %%
a['Top Tech Products Exported'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Top Tech Products Exported'>

# %%
# Numerical variables
a['Market Share (%)'].plot(kind = 'hist', bins = 10, grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
a['Market Share (%)'].plot(kind = 'hist', bins = 10, grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
a.sample(2)
# Out:
#     Country  Year    Tech Sector  Market Share (%)  R&D Investment (in USD)  \
# 138   China  2014             AI         46.730623             8.335051e+10
# 636   Japan  2011  Semiconductor         40.339315             5.128309e+10
#
#      Number of Patents Filed (Annual)  Number of Tech Companies  \
# 138                              7993                       571
# 636                              4232                       136
#
#      Tech Exports (in USD)  Number of Startups  \
# 138           2.199540e+10                 479
# 636           1.546279e+11                  18
#
#      Venture Capital Funding (in USD)  Global Innovation Ranking  \
# 138                      3.398615e+10                         19
# 636                      1.820991e+10                          4
#
#      Internet Penetration (%)  5G Network Coverage (%)  \
# 138                 46.895063                89.277726
# 636                 49.215569                52.385092
#
# ...

# %%
a['Global Innovation Ranking'].mean()
# Out:
# 10.003

# %%
a['Global Innovation Ranking'].median()
# Out:
# 10.0

# %%
a['Global Innovation Ranking'].std()
# Out:
# 5.53331804694151

# %%
a['Global Innovation Ranking'].plot(kind = 'box', grid = True, title = 'ranking')
# Out:
# <Axes: title={'center': 'ranking'}>

# %%
a['Number of Patents Filed (Annual)'].median()
# Out:
# 5021.0

# %%
a['Number of Patents Filed (Annual)'].plot(kind = 'box', grid = True, title = 'patents')
# Out:
# <Axes: title={'center': 'patents'}>

# %%
q1 = a['Global Innovation Ranking'].quantile(0.25)
q3 = a['Global Innovation Ranking'].quantile(0.75)
IQR = q3-q1
print(q1, q3, IQR)
# Out:
# 5.0 15.0 10.0

# %%
q1 = a['Number of Patents Filed (Annual)'].quantile(0.25)
q3 = a['Number of Patents Filed (Annual)'].quantile(0.75)
IQR = q3-q1
print(q1, q3, IQR)
# Out:
# 2789.5 7569.5 4780.0

# %%
a['University Research Collaborations'].median()
# Out:
# 100.0

# %%
a['University Research Collaborations'].plot(kind = 'box', grid = True, title = 'university')
# Out:
# <Axes: title={'center': 'university'}>

# %%
a['Number of Startups'].median()
# Out:
# 257.5

# %%
a.shape
# Out:
# (1000, 16)

# %%
a['Number of Startups'].plot(kind = 'box', grid = True, title = 'startups')
# Out:
# <Axes: title={'center': 'startups'}>

# %%
a['Internet Penetration (%)'].plot(kind = 'hist', bins = 10, grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
a['Global Innovation Ranking'].plot(kind = 'hist', bins = 10, grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
a['Global Innovation Ranking'].plot(kind = 'hist', bins = 5, grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
a['Number of Startups'].plot(kind = 'hist', bins = 5, grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
a['Number of Tech Workers'].median()
# Out:
# 505236.0

# %%
a['Number of Tech Workers'].plot(kind = 'box', grid = True, title = 'Tech Workers')
# Out:
# <Axes: title={'center': 'Tech Workers'}>

# %%
a['Number of Tech Companies'].median()
# Out:
# 998.5

# %%
a['Number of Tech Companies'].plot(kind = 'box', grid = True, title = 'Tech Companies')
# Out:
# <Axes: title={'center': 'Tech Companies'}>

# %%
a.sample(2)
# Out:
#     Country  Year         Tech Sector  Market Share (%)  \
# 220   Japan  2017  Telecommunications         13.005655
# 304   Japan  2003                  AI         44.492443
#
#      R&D Investment (in USD)  Number of Patents Filed (Annual)  \
# 220             3.000700e+10                              6757
# 304             7.244628e+10                              5812
#
#      Number of Tech Companies  Tech Exports (in USD)  Number of Startups  \
# 220                       114           1.600093e+11                  71
# 304                      1568           7.136516e+10                 461
#
#      Venture Capital Funding (in USD)  Global Innovation Ranking  \
# 220                      2.729118e+10                         18
# 304                      1.357875e+10                          6
#
#      Internet Penetration (%)  5G Network Coverage (%)  \
# 220                 74.690894                64.973523
# 304                 48.388919                82.215368
#
# ...

# %%
# Bivariate analysis
# Numerical and Numerical varibales analysis
a[['Number of Patents Filed (Annual)', 'Number of Tech Companies']].plot(kind = 'scatter', x = 'Number of Patents Filed (Annual)', y = 'Number of Tech Companies', title = 'Correlation', xlabel = 'Patents', ylabel = 'Companies')
# Out:
# <Axes: title={'center': 'Correlation'}, xlabel='Patents', ylabel='Companies'>

# %%
a[['Number of Startups', 'Global Innovation Ranking']].plot(kind = 'scatter', x = 'Number of Startups', y = 'Global Innovation Ranking', title = 'Correlation', xlabel = 'startups', ylabel = 'Ranking')
# Out:
# <Axes: title={'center': 'Correlation'}, xlabel='startups', ylabel='Ranking'>

# %%
a[['Global Innovation Ranking', 'University Research Collaborations']].plot(kind = 'scatter', x = 'Global Innovation Ranking', y = 'University Research Collaborations', title = 'Correlation', xlabel = 'Ranking', ylabel = 'Collaborations')
# Out:
# <Axes: title={'center': 'Correlation'}, xlabel='Ranking', ylabel='Collaborations'>

# %%
a[['Number of Tech Companies', 'Number of Tech Workers']].plot(kind = 'scatter', x = 'Number of Tech Companies', y = 'Number of Tech Workers', title = 'Correlation', xlabel = 'companies', ylabel = 'workers')
# Out:
# <Axes: title={'center': 'Correlation'}, xlabel='companies', ylabel='workers'>

# %%
a['Number of Tech Companies'].corr(a['Number of Tech Workers'])
# Out:
# -0.06818562818825419

# %%
a['Global Innovation Ranking'].corr(a['University Research Collaborations'])
# Out:
# 0.012041098654937894

# %%
a['Number of Startups'].corr(a['Global Innovation Ranking'])
# Out:
# -0.04005464248767335

# %%
a['Number of Patents Filed (Annual)'].corr(a['Number of Tech Companies'])
# Out:
# -0.016984293297461213

# %%
a[['Number of Startups', 'University Research Collaborations']].plot(kind = 'scatter', x = 'Number of Startups', y = 'University Research Collaborations', title = 'Correlation', xlabel = 'startups', ylabel = 'collaborations')
# Out:
# <Axes: title={'center': 'Correlation'}, xlabel='startups', ylabel='collaborations'>

# %%
a['Number of Startups'].corr(a['University Research Collaborations'])
# Out:
# -0.024677497714773254

# %%
a.sample(2)
# Out:
#     Country  Year    Tech Sector  Market Share (%)  R&D Investment (in USD)  \
# 80    Japan  2003  Biotechnology         20.319964             5.222673e+10
# 346   China  2022       Robotics          7.670138             1.931439e+09
#
#      Number of Patents Filed (Annual)  Number of Tech Companies  \
# 80                               5219                      1877
# 346                              5354                      1054
#
#      Tech Exports (in USD)  Number of Startups  \
# 80            9.805478e+10                  77
# 346           4.910459e+10                 281
#
#      Venture Capital Funding (in USD)  Global Innovation Ranking  \
# 80                       1.185265e+10                         19
# 346                      3.082384e+10                          8
#
#      Internet Penetration (%)  5G Network Coverage (%)  \
# 80                  45.100839                36.400472
# 346                 84.538635                31.620964
#
# ...

# %%
a['Market Share (%)'] = a['Market Share (%)'].astype('int')
a['Internet Penetration (%)'] = a['Internet Penetration (%)'].astype('int')
a['5G Network Coverage (%)'] = a['5G Network Coverage (%)'].astype('int')

# %%
a.sample(2)
# Out:
#     Country  Year Tech Sector  Market Share (%)  R&D Investment (in USD)  \
# 739   China  2008          AI                15             4.689699e+10
# 883   Japan  2019    Robotics                20             4.769371e+10
#
#      Number of Patents Filed (Annual)  Number of Tech Companies  \
# 739                              3027                      1477
# 883                              6095                      1163
#
#      Tech Exports (in USD)  Number of Startups  \
# 739           1.883804e+11                 132
# 883           2.038074e+10                 299
#
#      Venture Capital Funding (in USD)  Global Innovation Ranking  \
# 739                      2.425624e+10                          2
# 883                      2.315595e+10                          7
#
#      Internet Penetration (%)  5G Network Coverage (%)  \
# 739                        68                       76
# 883                        61                       25
#
# ...

# %%
# Categorical and Categorical variables analysis
b = a.groupby(['Country', 'Tech Sector'])['Tech Sector'].count().unstack()
b.plot(kind = 'bar', stacked = True, title = 'country vs techsector', xlabel = 'country',ylabel = 'count', figsize = (10, 5))
# Out:
# <Axes: title={'center': 'country vs techsector'}, xlabel='country', ylabel='count'>

# %%
b = a.groupby(['Country', 'Top Tech Products Exported'])['Top Tech Products Exported'].count().unstack()
b.plot(kind = 'bar', stacked = True, title = 'country vs techexported', xlabel = 'country',ylabel = 'count', figsize = (15, 5))
# Out:
# <Axes: title={'center': 'country vs techexported'}, xlabel='country', ylabel='count'>

# %%
b = a.groupby(['Year', 'Top Tech Products Exported'])['Top Tech Products Exported'].count().unstack()
b.plot(kind = 'bar', stacked = True, title = 'country vs techexported', xlabel = 'country',ylabel = 'count', figsize = (15, 5))
# Out:
# <Axes: title={'center': 'country vs techexported'}, xlabel='country', ylabel='count'>

# %%
from scipy.stats import chi2_contingency

# %%
b = pd.crosstab(a['Country'], a['Tech Sector'])
b
# Out:
# Tech Sector  AI  Biotechnology  Cloud Computing  Robotics  Semiconductor  \
# Country
# China        70             74               66        76             69
# Japan        63             70               75        79             75
#
# Tech Sector  Software  Telecommunications
# Country
# China              74                  68
# Japan              70                  71

# %%
chi2, p_value, dof, expected = chi2_contingency(b)
print(chi2, p_value, dof, expected)
# Out:
# 1.5019781487414197 0.9593630503776007 6 [[66.101 71.568 70.077 77.035 71.568 71.568 69.083]
#  [66.899 72.432 70.923 77.965 72.432 72.432 69.917]]

# %%
b = pd.crosstab(a['Country'], a['Top Tech Products Exported'])
b
# Out:
# Top Tech Products Exported  5G Equipment  AI Chips  Cloud Servers  Robots  \
# Country
# China                                105       108            102      96
# Japan                                 76       100            127     107
#
# Top Tech Products Exported  Semiconductors
# Country
# China                                   86
# Japan                                   93

# %%
chi2, p_value, dof, expected = chi2_contingency(b)
print(chi2, p_value, dof, expected)
# Out:
# 8.517467548284722 0.07435952502012462 4 [[ 89.957 103.376 113.813 100.891  88.963]
#  [ 91.043 104.624 115.187 102.109  90.037]]

# %%
a.sample(2)
# Out:
#     Country  Year    Tech Sector  Market Share (%)  R&D Investment (in USD)  \
# 70    Japan  2006  Biotechnology                45             7.077547e+10
# 551   China  2006             AI                17             3.853878e+10
#
#      Number of Patents Filed (Annual)  Number of Tech Companies  \
# 70                               3065                       933
# 551                              8388                       206
#
#      Tech Exports (in USD)  Number of Startups  \
# 70            9.561086e+10                 139
# 551           2.284646e+10                 409
#
#      Venture Capital Funding (in USD)  Global Innovation Ranking  \
# 70                       3.320105e+10                          7
# 551                      4.365044e+10                          9
#
#      Internet Penetration (%)  5G Network Coverage (%)  \
# 70                         76                       84
# 551                        43                       28
#
# ...

# %%
# Categorical and Numerical variables
import seaborn as sns
sns.lineplot(data = a, x = 'Country', y = 'R&D Investment (in USD)')
plt.show()

# %%
from statsmodels.stats.weightstats import ztest

# %%
data1 = a['R&D Investment (in USD)'][a['Country'] == 'China']
data2 = a['R&D Investment (in USD)'][a['Country'] == 'Japan']

# Perform z-test
z_statistic, p_value = ztest(data1, data2)
print("Z-statistic:", z_statistic)
print("P-value:", p_value)
# Out:
# Z-statistic: -0.13195536174320896
# P-value: 0.8950195990883041

# %%
sns.lineplot(data = a, x = 'Country', y = 'Number of Patents Filed (Annual)')
plt.show()

# %%
data1 = a['Number of Patents Filed (Annual)'][a['Country'] == 'China']
data2 = a['Number of Patents Filed (Annual)'][a['Country'] == 'Japan']

# Perform z-test
z_statistic, p_value = ztest(data1, data2)
print("Z-statistic:", z_statistic)
print("P-value:", p_value)
# Out:
# Z-statistic: 2.0377860420225242
# P-value: 0.04157133487018871

# %%
sns.lineplot(data = a, x = 'Country', y = 'Number of Tech Companies')
plt.show()

# %%
data1 = a['Number of Tech Companies'][a['Country'] == 'China']
data2 = a['Number of Tech Companies'][a['Country'] == 'Japan']

# Perform z-test
z_statistic, p_value = ztest(data1, data2)
print("Z-statistic:", z_statistic)
print("P-value:", p_value)
# Out:
# Z-statistic: 1.4974632579659968
# P-value: 0.13427275905656708

# %%
sns.lineplot(data = a, x = 'Country', y = 'Tech Exports (in USD)')
plt.show()

# %%
sns.lineplot(data = a, x = 'Country', y = 'Number of Startups')
plt.show()

# %%
data1 = a['Number of Startups'][a['Country'] == 'China']
data2 = a['Number of Startups'][a['Country'] == 'Japan']

# Perform z-test
z_statistic, p_value = ztest(data1, data2)
print("Z-statistic:", z_statistic)
print("P-value:", p_value)
# Out:
# Z-statistic: 1.5418746886665993
# P-value: 0.12310404781509068

# %%
sns.lineplot(data = a, x = 'Country', y = 'Global Innovation Ranking')
plt.show()

# %%
sns.lineplot(data = a, x = 'Country', y = 'University Research Collaborations')
plt.show()

# %%
sns.lineplot(data = a, x = 'Country', y = 'Number of Tech Workers')
plt.show()

# %%
plt.figure(figsize = (12, 5))
sns.lineplot(data = a, x = 'Tech Sector', y = 'R&D Investment (in USD)')
plt.show()

# %%
plt.figure(figsize = (12, 5))
sns.lineplot(data = a, x = 'Tech Sector', y = 'Number of Patents Filed (Annual)')
plt.show()

# %%
plt.figure(figsize = (12, 5))
sns.lineplot(data = a, x = 'Tech Sector', y = 'Number of Tech Companies')
plt.show()

# %%
plt.figure(figsize = (12, 5))
sns.lineplot(data = a, x = 'Tech Sector', y = 'Number of Startups')
plt.show()

# %%
plt.figure(figsize = (12, 5))
sns.lineplot(data = a, x = 'Tech Sector', y = 'University Research Collaborations')
plt.show()

# %%
plt.figure(figsize = (12, 5))
sns.lineplot(data = a, x = 'Tech Sector', y = 'Number of Tech Workers')
plt.show()

# %%
sns.lineplot(data = a, x = 'Country', y = 'Market Share (%)')
plt.show()
